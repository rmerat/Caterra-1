# %%
import cv2
import os
import matplotlib.pyplot as plt

# %%
dirname = os.path.dirname()
print(dirname)
#filename = os.path.join(dirname, 'relative/path/to/file/you/want')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [18], line 1
# ----> 1 dirname = os.path.dirname()
#       2 print(dirname)
#
# TypeError: dirname() missing 1 required positional argument: 'p'

# %%
cwd = os.getcwd()

# %%
cwd
# Out:
# '/home/roxane/Desktop/M3_2022/Caterra_2912/Caterra/CropRowDetection'

# %%
#print(os.path.join(image_folder, name_images))
#image = cv2.imread(os.path.join(image_folder, name_images))
image = cv2.imread('CropRowDetection/Images/crop_row_013.jpg') #os.path.join('/home/roxane/Desktop/M3_2022/Caterra_2912/Caterra/CropRowDetection/Images/', 'crop_row_013.JPG'))
# Out:
# [ WARN:0@136.738] global /io/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('CropRowDetection/Images/crop_row_013.jpg'): can't open/read file: check file path/integrity

# %%
plt.imshow(image)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 plt.imshow(image)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py:2623, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
# ...

# %%
import SettingUp

folder = '/home/roxane/Desktop/M3_2022/Caterra/dataset_straigt_lines/'
lst = os.listdir(folder)
lst.sort()
name_images = [img for img in lst 
                if img.endswith(".jpg") or
                    img.endswith(".jpeg") or
                    img.endswith(".JPG") or
                    img.endswith("png")]

images = []
for idx, name in enumerate(name_images):
    image = cv2.imread(os.path.join(folder, name))
    if image is not None : 
        #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        #image = SettingUp.image_resize(image, output_width=320)
        filename = '/home/roxane/Desktop/M3_2022/Caterra_2912/Caterra/CropRowDetection/ImagesCropRow/CR' + str(idx).zfill(3) + '.jpg'
        print(filename)
        cv2.imwrite(filename, image)
# Out:
# /home/roxane/Desktop/M3_2022/Caterra_2912/Caterra/CropRowDetection/ImagesCropRow/CR000.jpg
# /home/roxane/Desktop/M3_2022/Caterra_2912/Caterra/CropRowDetection/ImagesCropRow/CR001.jpg
# /home/roxane/Desktop/M3_2022/Caterra_2912/Caterra/CropRowDetection/ImagesCropRow/CR002.jpg
# /home/roxane/Desktop/M3_2022/Caterra_2912/Caterra/CropRowDetection/ImagesCropRow/CR003.jpg
# /home/roxane/Desktop/M3_2022/Caterra_2912/Caterra/CropRowDetection/ImagesCropRow/CR004.jpg
# /home/roxane/Desktop/M3_2022/Caterra_2912/Caterra/CropRowDetection/ImagesCropRow/CR005.jpg
# /home/roxane/Desktop/M3_2022/Caterra_2912/Caterra/CropRowDetection/ImagesCropRow/CR006.jpg
# /home/roxane/Desktop/M3_2022/Caterra_2912/Caterra/CropRowDetection/ImagesCropRow/CR007.jpg
# /home/roxane/Desktop/M3_2022/Caterra_2912/Caterra/CropRowDetection/ImagesCropRow/CR008.jpg
# /home/roxane/Desktop/M3_2022/Caterra_2912/Caterra/CropRowDetection/ImagesCropRow/CR009.jpg
# ...

# %%
plt.imshow(image)

# %%
idx = 4
print('/home/roxane/Desktop/M3_2022/Caterra_2912/Caterra/CropRowDetection/ImagesCropRow/CR' + str(idx).zfill(3))
# Out:
# /home/roxane/Desktop/M3_2022/Caterra_2912/Caterra/CropRowDetection/ImagesCropRow/CR004

# %%
import cv2
import numpy as np
image = cv2.imread('/home/roxane/Desktop/M3_2022/Caterra_2912/Caterra/CropRowDetection/ImagesCropRow/CR000.jpg')

# %%
image.shape
# Out:
# (240, 320, 3)

# %%
image = cv2.imread('/home/roxane/Desktop/M3_2022/Caterra/dataset_straigt_lines/crop_row_001.JPG')
image.shape
# Out:
# (240, 320, 3)

# %%
import os
# Function to rename multiple files
def main():
	i = 0
	path="/home/roxane/Desktop/M3_2022/Caterra_2912/Caterra/CropRowDetection/ImagesCropRow/"
	for filename in os.listdir(path):
		my_dest ="crop" + str(i).zfill(3) + ".jpg"
		my_source =path + filename
		my_dest =path + my_dest
		# rename() function will
		# rename all the files
		os.rename(my_source, my_dest)
		i += 1
# Driver Code
if __name__ == '__main__':
	# Calling main() function
	main()

# %%
import csv

with open ('/home/roxane/Desktop/ImageClassification.txt', 'r') as f:
    names = [row[0] for row in csv.reader(f,delimiter='\t')]
with open ('/home/roxane/Desktop/ImageClassification.txt', 'r') as f:
    types = [row[1] for row in csv.reader(f,delimiter='\t')]

# %%
import cv2 
imgs = []
names_straight = []

for n, t in zip(names, types):
    if (int(t)==1):
        print(n)
        imgs.append(cv2.imread('/home/roxane/Desktop/Images/' + n))
        names_straight.append(n)
# Out:
# crop_row_001.JPG
# crop_row_002.JPG
# crop_row_008.JPG
# crop_row_013.JPG
# crop_row_020.JPG
# crop_row_021.JPG
# crop_row_023.JPG
# crop_row_047.JPG
# crop_row_051.JPG
# crop_row_053.JPG
# crop_row_057.JPG
# crop_row_064.JPG
# crop_row_095.JPG
# crop_row_099.JPG
# crop_row_114.JPG
# crop_row_115.JPG
# crop_row_116.JPG
# crop_row_118.JPG
# crop_row_121.JPG
# crop_row_122.JPG
# crop_row_127.JPG
# crop_row_128.JPG
# crop_row_143.JPG
# crop_row_152.JPG
# crop_row_159.JPG
# crop_row_178.JPG
# crop_row_189.JPG
# crop_row_192.JPG
# crop_row_194.JPG
# crop_row_196.JPG
# crop_row_211.JPG
# crop_row_213.JPG
# crop_row_216.JPG
# crop_row_219.JPG
# crop_row_220.JPG
# crop_row_238.JPG
# crop_row_241.JPG
# crop_row_243.JPG
# crop_row_247.JPG
# crop_row_256.JPG
# crop_row_257.JPG
# crop_row_258.JPG
# crop_row_259.JPG
# crop_row_261.JPG
# crop_row_262.JPG
# crop_row_271.JPG
# crop_row_272.JPG
# crop_row_273.JPG

# %%
plt.imshow(imgs[0])

# %%
for n, img in zip(names_straight, imgs)  : 
    filename = '/home/roxane/Desktop/M3_2022/Caterra_2912/Caterra/CropRowDetection/Images_New/' + n
    print(filename)
    cv2.imwrite(filename,  img)
# Out:
# /home/roxane/Desktop/M3_2022/Caterra_2912/Caterra/CropRowDetection/Images_New/crop_row_001.JPG
# /home/roxane/Desktop/M3_2022/Caterra_2912/Caterra/CropRowDetection/Images_New/crop_row_002.JPG
# /home/roxane/Desktop/M3_2022/Caterra_2912/Caterra/CropRowDetection/Images_New/crop_row_008.JPG
# /home/roxane/Desktop/M3_2022/Caterra_2912/Caterra/CropRowDetection/Images_New/crop_row_013.JPG
# /home/roxane/Desktop/M3_2022/Caterra_2912/Caterra/CropRowDetection/Images_New/crop_row_020.JPG
# /home/roxane/Desktop/M3_2022/Caterra_2912/Caterra/CropRowDetection/Images_New/crop_row_021.JPG
# /home/roxane/Desktop/M3_2022/Caterra_2912/Caterra/CropRowDetection/Images_New/crop_row_023.JPG
# /home/roxane/Desktop/M3_2022/Caterra_2912/Caterra/CropRowDetection/Images_New/crop_row_047.JPG
# /home/roxane/Desktop/M3_2022/Caterra_2912/Caterra/CropRowDetection/Images_New/crop_row_051.JPG
# /home/roxane/Desktop/M3_2022/Caterra_2912/Caterra/CropRowDetection/Images_New/crop_row_053.JPG
# ...

# %%
'/home/roxane/Desktop/M3_2022/crop_dataset_annoted/GT data'
